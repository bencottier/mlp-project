# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import re
import os
from pathlib import Path

# %%
data_path = Path("../data/mathematics_dataset-v1.0/")

# %%
# !ls ../data/mathematics_dataset-v1.0/extrapolate
# Out:
# algebra__polynomial_roots_big.txt
# arithmetic__add_or_sub_big.txt
# arithmetic__add_sub_multiple_longer.txt
# arithmetic__div_big.txt
# arithmetic__mixed_longer.txt
# arithmetic__mul_big.txt
# arithmetic__mul_div_multiple_longer.txt
# comparison__closest_more.txt
# comparison__kth_biggest_more.txt
# comparison__sort_more.txt
# measurement__conversion.txt
# numbers__place_value_big.txt
# numbers__round_number_big.txt
# probability__swr_p_level_set_more_samples.txt
# probability__swr_p_sequence_more_samples.txt

# %%
train_files = [
    "algebra__polynomial_roots.txt",
    "arithmetic__add_or_sub.txt",
    "arithmetic__add_sub_multiple.txt",
    "arithmetic__div.txt",
    "arithmetic__mixed.txt",
    "arithmetic__mul.txt",
    "arithmetic__mul_div_multiple.txt",
    "comparison__closest.txt",
    "comparison__kth_biggest.txt",
    "comparison__sort.txt",
    "measurement__conversion.txt",
    "numbers__place_value.txt",
    "numbers__round_number.txt",
    "probability__swr_p_level_set.txt",
    "probability__swr_p_sequence.txt",
]

# %%
feature_keys = ["big", "longer", "more", "", "more_samples"]
difficulties = ['train-easy', 'train-medium', 'train-hard']

# %%
for fn in train_files:
    print("\n" + "=" * len(fn))
    print(fn)
    print("=" * len(fn))
    for difficulty in difficulties:
        print("\n" + difficulty + "\n")
        with open(data_path/difficulty/fn, 'r') as f:
            for i, line in enumerate(f.readlines()):
                if i > 5: break
                print(line.strip())
# Out:
# =============================
# algebra__polynomial_roots.txt
# =============================
#
# train-easy
#
# Solve -3*h**2/2 - 24*h - 45/2 = 0 for h.
# -15, -1
# Factor -n**2/3 - 25*n - 536/3.
# -(n + 8)*(n + 67)/3
# Let c**3/9 - 11*c**2/3 + 35*c - 75 = 0. What is c?
# 3, 15
#
# train-medium
#
# Factor 2*k**2/5 - 44598*k/5 + 44596/5.
# 2*(k - 22298)*(k - 1)/5
# Solve -3*w**3 + 1374*w**2 - 5433*w - 6810 = 0 for w.
# -1, 5, 454
# Suppose 27*u**3 - 7329*u**2 = 0. Calculate u.
# 0, 2443/9
#
# train-hard
#
# Determine b so that -18*b**5 + 66654*b**4 - 3739744*b**3 - 3836048*b**2 + 1662112*b + 1691744 = 0.
# -1, -2/3, 2/3, 58, 3646
# Find r, given that 3*r**3 + 7644783*r**2 = 0.
# -2548261, 0
# Suppose 290*b**5/9 - 6031124*b**4/9 + 10451403836*b**3/3 + 32021141536*b**2/9 - 62071651798*b/9 - 432556804/3 = 0. What is b?
# -2, -3/145, 1, 10399
#
# ==========================
# arithmetic__add_or_sub.txt
# ==========================
#
# train-easy
#
# What is -5 - 110911?
# -110916
# What is -0.188 + -0.814?
# -1.002
# Sum 259 and -46.
# 213
#
# train-medium
#
# Total of 0.06 and -1977321735.
# -1977321734.94
# Add together 2 and 436273715.
# 436273717
# Calculate 4062037 + -0.07.
# 4062036.93
#
# train-hard
#
# Work out -0.5 - -1782838373837.
# 1782838373836.5
# What is 59086632155.4 + -3?
# 59086632152.4
# Total of 9207641 and -0.541.
# 9207640.459
#
# ================================
# arithmetic__add_sub_multiple.txt
# ================================
#
# train-easy
#
# What is 1 + -9 - -5 - -1?
# -2
# -2 + 0 + (3 - 1)
# 0
# Calculate 8 - (0 + 7 + -4).
# 5
#
# train-medium
#
# What is 12 + -24 + (-11 - -2)?
# -21
# Evaluate 60 - ((36 - 34) + 33).
# 25
# Evaluate 0 - 0 - (14 + -58 + 39).
# 5
#
# train-hard
#
# What is the value of 2 + 21 + 2570 + -2684?
# -91
# Evaluate (-17 - 2 - -39) + -51 + -82.
# -113
# Calculate (71 - (187 + -94)) + (0 - 3).
# -25
#
# ===================
# arithmetic__div.txt
# ===================
#
# train-easy
#
# What is -280 divided by -10?
# 28
# -107 divided by -1
# 107
# Calculate -4 divided by 3.
# -4/3
#
# train-medium
#
# Divide -57912 by -57.
# 1016
# What is 391404 divided by -6?
# -65234
# What is 24626 divided by -12313?
# -2
#
# train-hard
#
# -103692 divided by -3905
# 103692/3905
# Divide -1560 by 125780.
# -78/6289
# Calculate 41690064 divided by 66811.
# 624
#
# =====================
# arithmetic__mixed.txt
# =====================
#
# train-easy
#
# 15 + (7 + -17)/1
# 5
# 10/(-60) + 14/(-24)
# -3/4
# Calculate 12/198 - 600/99.
# -6
#
# train-medium
#
# Calculate (4/14)/(954/96831).
# 29
# What is the value of (9/6)/((-2247)/1712)?
# -8/7
# Evaluate 2054/9243 + 22/36.
# 5/6
#
# train-hard
#
# What is the value of (-106)/(-160) + 2811/(-4685)?
# 1/16
# Evaluate ((-10224)/(-189) - 5) + 56/(-588).
# 49
# Calculate (-195)/(-45) + -2 + (314/(-60) - 24/(-60)).
# -5/2
#
# ===================
# arithmetic__mul.txt
# ===================
#
# train-easy
#
# Work out 4 * 4.45.
# 17.8
# What is the product of -0.4301 and -0.4?
# 0.17204
# Calculate -0.2*0.57.
# -0.114
#
# train-medium
#
# What is 5 times 134945?
# 674725
# Multiply 0 and -169144.
# 0
# Multiply -9344 and 0.
# 0
#
# train-hard
#
# What is 2 times 376.54543?
# 753.09086
# What is -418009 times 3?
# -1254027
# Multiply 0.146 and -121864.
# -17792.144
#
# ================================
# arithmetic__mul_div_multiple.txt
# ================================
#
# train-easy
#
# (-29)/(-87)*(-18)/(-10)
# 3/5
# What is (-5)/20*-16*2/(-4)?
# -2
# What is the value of (-2*4/(-72))/(1/(-2))?
# -2/9
#
# train-medium
#
# What is the value of ((-26)/65)/(7/(-280))?
# 16
# What is the value of (-1603)/229*(-10)/7?
# 10
# Calculate 21/(-48)*10524/30695.
# -3/20
#
# train-hard
#
# What is 10*2*18690/(-44856)?
# -25/3
# Evaluate (81175/(-64940))/(2/12*2/(-4)).
# 15
# What is ((-260)/3)/2*167/((-108550)/(-975))?
# -65
#
# =======================
# comparison__closest.txt
# =======================
#
# train-easy
#
# Which is the closest to -1/3?  (a) -8/7  (b) 5  (c) -1.3
# a
# Which is the nearest to 27/5?  (a) 0.4  (b) 0.2  (c) -0.5  (d) -0.1
# a
# Which is the closest to -4/17?  (a) 4/7  (b) -42/11  (c) 2
# a
#
# train-medium
#
# Which is the nearest to -1/4?  (a) 2/15  (b) 1/2  (c) 4.1  (d) 3
# a
# What is the nearest to 5/13 in 0.47, 1, 3/2, 2?
# 0.47
# Which is the closest to 1?  (a) -6  (b) -4  (c) 3  (d) -376
# c
#
# train-hard
#
# Which is the closest to 2?  (a) -7659/7  (b) -2  (c) 4  (d) 0.14
# d
# Which is the nearest to 8?  (a) 2/10513  (b) 1  (c) 0.3  (d) 2  (e) 0.2  (f) -83
# d
# Which is the nearest to -3/529?  (a) 3/4  (b) 0.1  (c) -5  (d) -0.5
# b
#
# ===========================
# comparison__kth_biggest.txt
# ===========================
#
# train-easy
#
# Which is the smallest value?  (a) 2/13  (b) 5  (c) 0.7
# a
# Which is the third smallest value?  (a) 6  (b) 0.2  (c) -2  (d) 5  (e) -0.054
# b
# Which is the biggest value?  (a) -0.05  (b) -2685  (c) 1
# c
#
# train-medium
#
# Which is the fourth smallest value?  (a) -5  (b) 291577  (c) -0.9  (d) 0.3  (e) 0.2
# d
# What is the second smallest value in 0.1, 4, 71/44?
# 71/44
# Which is the biggest value?  (a) 30  (b) -3/53  (c) -1/8  (d) 0.4  (e) -0.3
# a
#
# train-hard
#
# What is the second biggest value in 0.1, 14, 305, -1, -0.136, 1?
# 14
# What is the second biggest value in 525, -5.3, 399/5?
# 399/5
# What is the smallest value in -155497, -0.3, 0, 137?
# -155497
#
# ====================
# comparison__sort.txt
# ====================
#
# train-easy
#
# Put -534, 4, 3 in descending order.
# 4, 3, -534
# Put 3, -5, -3, 13 in increasing order.
# -5, -3, 3, 13
# Put 21, 2/15, 26 in descending order.
# 26, 21, 2/15
#
# train-medium
#
# Sort 221, -2, 80, -5, -1 in decreasing order.
# 221, 80, -1, -2, -5
# Put -2, 3, 462, -4, -176 in ascending order.
# -176, -4, -2, 3, 462
# Sort 16, 0, 2, -4 in ascending order.
# -4, 0, 2, 16
#
# train-hard
#
# Put 198, -45, 5, -2, -18, 2, 3 in decreasing order.
# 198, 5, 3, 2, -2, -18, -45
# Sort -0.2, 42826, 14, 501 in decreasing order.
# 42826, 501, 14, -0.2
# Sort -0.06, 2/3, 46, -18, -414 in descending order.
# 46, 2/3, -0.06, -18, -414
#
# ===========================
# measurement__conversion.txt
# ===========================
#
# train-easy
#
# How many micrometers are there in twenty-one quarters of a millimeter?
# 5250
# What is fourty-three halves of a meter in millimeters?
# 21500
# Convert 7.49573mg to grams.
# 0.00749573
#
# train-medium
#
# How many months are there in one fifth of a millennium?
# 2400
# What is 23/3 of a day in hours?
# 184
# How many milligrams are there in 50.05692kg?
# 50056920
#
# train-hard
#
# What is 3/5 of a millimeter in micrometers?
# 600
# What is 2/21 of a week in seconds?
# 57600
# What is 88937.07ms in minutes?
# 1.4822845
#
# ========================
# numbers__place_value.txt
# ========================
#
# train-easy
#
# What is the hundreds digit of 31253?
# 2
# What is the units digit of 8196?
# 6
# What is the ten thousands digit of 37118?
# 3
#
# train-medium
#
# What is the units digit of 80577?
# 7
# What is the hundred thousands digit of 393392?
# 3
# What is the thousands digit of 10117253?
# 7
#
# train-hard
#
# What is the millions digit of 9967193?
# 9
# What is the hundred millions digit of 295868867?
# 2
# What is the hundred millions digit of 127051896?
# 1
#
# =========================
# numbers__round_number.txt
# =========================
#
# train-easy
#
# What is -0.0006832 rounded to 5 decimal places?
# -0.00068
# What is -1875400 rounded to the nearest 100000?
# -1900000
# What is 0.000293695 rounded to 5 dps?
# 0.00029
#
# train-medium
#
# Round 1.72315 to two decimal places.
# 1.72
# Round 49.26661 to the nearest ten.
# 50
# Round 0.0165733 to 3 decimal places.
# 0.017
#
# train-hard
#
# What is -4483293740 rounded to the nearest 100000?
# -4483300000
# What is 76099930350 rounded to the nearest one million?
# 76100000000
# Round -1.7653370439 to five decimal places.
# -1.76534
#
# ================================
# probability__swr_p_level_set.txt
# ================================
#
# train-easy
#
# What is prob of picking 1 b and 1 p when two letters picked without replacement from tpppbbpbbb?
# 4/9
# What is prob of picking 1 p and 1 y when two letters picked without replacement from {y: 1, p: 2, z: 1, n: 2}?
# 2/15
# Four letters picked without replacement from {y: 6, b: 1, u: 4}. What is prob of picking 2 y and 2 u?
# 3/11
#
# train-medium
#
# Three letters picked without replacement from zzqzzzfqfzzfqtffftf. Give prob of picking 1 f and 2 z.
# 49/323
# Calculate prob of picking 3 t and 1 l when four letters picked without replacement from {r: 2, l: 2, n: 2, f: 2, t: 5}.
# 4/143
# Three letters picked without replacement from pooo. Give prob of picking 3 o.
# 1/4
#
# train-hard
#
# What is prob of picking 2 f and 1 v when three letters picked without replacement from vvafvvvavavvvvvfvfv?
# 13/323
# Four letters picked without replacement from {e: 5, g: 2, k: 8}. What is prob of picking 4 e?
# 1/273
# What is prob of picking 1 h and 3 x when four letters picked without replacement from xkkxkhx?
# 1/35
# ===============================
# probability__swr_p_sequence.txt
# ===============================
#
# train-easy
#
# What is prob of sequence ccbc when four letters picked without replacement from nnscspb?
# 0
# Three letters picked without replacement from {g: 3, w: 1, t: 7, u: 3}. Give prob of sequence tuw.
# 1/104
# Three letters picked without replacement from dxaxxaaxxxaax. What is prob of sequence aad?
# 5/429
#
# train-medium
#
# Two letters picked without replacement from {p: 12, v: 6, k: 1}. Give prob of sequence vk.
# 1/57
# What is prob of sequence dd when two letters picked without replacement from dnnonnodonvdnnv?
# 1/35
# Calculate prob of sequence yovy when four letters picked without replacement from {o: 2, y: 4, v: 4}.
# 2/105
#
# train-hard
#
# Two letters picked without replacement from uxjqxjjqxuxqx. What is prob of sequence xj?
# 5/52
# What is prob of sequence dd when two letters picked without replacement from cccadcdaddd?
# 2/11
# Calculate prob of sequence fxf when three letters picked without replacement from {a: 4, u: 3, f: 2, x: 8}.
# 1/255

# %%
fn = "arithmetic__add_or_sub.txt"

# %%
# Regex patterns
float_pattern = "[+-]?(?:[0-9]*[.])?[0-9]+"  # ?: for non-capturing group
float_pattern = re.compile(float_pattern)

# %%
matches = re.findall(float_pattern, "What is -0.188 + -0.814?")

# %%
print(matches)
# Out:
# ['-0.188', '-0.814']

# %%
float_results = dict()
for fn in train_files:
    print("\n" + "=" * len(fn))
    print(fn)
    print("=" * len(fn))
    for difficulty in difficulties:
        print("\n" + difficulty + "\n")
        with open(data_path/difficulty/fn, 'r') as f:
            avg_lens = []
            for i, line in enumerate(f):
#                 if i > 5: break
                line = line.strip()
                matches = re.findall(float_pattern, line)
                if i % int(5e5) == 0: print(matches)
                lens = [len(match) for match in matches]
                avg_len = sum(lens) / len(lens) if len(lens) > 0 else 0.
#                 avg_len = max(lens) if len(lens) > 0 else 0.
                avg_lens.append(avg_len)
            total_avg_len = sum(avg_lens) / len(avg_lens) if len(avg_lens) > 0 else 0.
            float_results[difficulty + '/' + fn] = total_avg_len
            print('Average feature: ', total_avg_len)
# Out:
# =============================
# algebra__polynomial_roots.txt
# =============================
#
# train-easy
#
# ['-3', '2', '2', '24', '45', '2', '0']
# ['35', '5', '45', '4', '165', '3', '55', '2', '30', '0']
# ['-3', '3', '4', '33', '2', '4', '3', '4', '33', '4']
# Average feature:  1.6958307381347562
#
# train-medium
#
# ['2', '2', '5', '44598', '5', '44596', '5']
# ['-3', '5', '987', '4', '1962', '3', '6', '2', '1965', '981', '0']
# ['8', '3', '20972', '2', '13760240', '20593200', '0']
# Average feature:  2.4275948104422063
#
# train-hard
#
# ['-18', '5', '66654', '4', '3739744', '3', '3836048', '2', '1662112', '1691744', '0']
# ['2', '5', '372', '4', '27080', '3', '202128', '2', '18926208', '149022720', '0']
# ['-2', '2', '13', '5624', '13', '1197120', '13']
# Average feature:  3.2544570248489006
#
# ==========================
# arithmetic__add_or_sub.txt
# ==========================
#
# train-easy
#
# ['-5', '110911']
# ['0.3', '445115']
# ['-1.5', '227230']
# Average feature:  5.206219456219456
#
# train-medium
#
# ['0.06', '-1977321735']
# ['4', '54838336.46']
# ['0.4', '0.0952769']
# Average feature:  7.7267046017046015
#
# train-hard
#
# ['-0.5', '-1782838373837']
# ['-274953089', '-7.1348']
# ['-243408125', '-106.33']
# Average feature:  10.298716673716674
#
# ================================
# arithmetic__add_sub_multiple.txt
# ================================
#
# train-easy
#
# ['1', '-9', '-5', '-1']
# ['3', '8', '-1', '0']
# ['6', '2', '1', '136', '141']
# Average feature:  1.559304171804419
#
# train-medium
#
# ['12', '-24', '-11', '-2']
# ['16', '20', '8', '-4', '12']
# ['-2', '14', '17', '-8']
# Average feature:  2.0100066225066984
#
# train-hard
#
# ['2', '21', '2570', '-2684']
# ['-2', '6', '-2', '-4', '1', '21']
# ['7', '20', '-12', '-4', '-6', '-43']
# Average feature:  2.374148192005407
#
# ===================
# arithmetic__div.txt
# ===================
#
# train-easy
#
# ['-280', '-10']
# ['-47', '60']
# ['-1', '-1581']
# Average feature:  2.619151869151869
#
# train-medium
#
# ['-57912', '-57']
# ['32383', '-47']
# ['-518', '7027']
# Average feature:  3.865008115008115
#
# train-hard
#
# ['-103692', '-3905']
# ['-8', '814477']
# ['1', '1396310']
# Average feature:  5.149848274848275
#
# =====================
# arithmetic__mixed.txt
# =====================
#
# train-easy
#
# ['15', '7', '-17', '1']
# ['16', '2', '-21', '-21']
# ['11', '-4', '-2', '24', '-135']
# Average feature:  1.7609477609478448
#
# train-medium
#
# ['4', '14', '954', '96831']
# ['-260', '-30', '-5', '-10', '-3']
# ['-124', '8', '7', '5868', '696']
# Average feature:  2.1717804592804977
#
# train-hard
#
# ['-106', '-160', '2811', '-4685']
# ['40', '-4200', '-147', '-20']
# ['76', '390', '12', '260', '25', '-66', '77']
# Average feature:  2.5621487853630347
#
# ===================
# arithmetic__mul.txt
# ===================
#
# train-easy
#
# ['4', '4.45']
# ['0.5', '50']
# ['-102.21', '0']
# Average feature:  4.11528974028974
#
# train-medium
#
# ['5', '134945']
# ['5', '40791']
# ['-346801', '0.5']
# Average feature:  5.640152265152265
#
# train-hard
#
# ['2', '376.54543']
# ['-96368758', '-5']
# ['-500.9434', '3.8']
# Average feature:  7.273796023796024
#
# ================================
# arithmetic__mul_div_multiple.txt
# ================================
#
# train-easy
#
# ['-29', '-87', '-18', '-10']
# ['-83', '747', '-2', '9', '-1']
# ['-1', '10', '-25', '-15', '-9']
# Average feature:  1.7392912267914733
#
# train-medium
#
# ['-26', '65', '7', '-280']
# ['-18', '-21', '-5', '-126', '-108', '-135']
# ['-28', '3', '-19', '-437', '-69']
# Average feature:  2.1371974871975064
#
# train-hard
#
# ['10', '2', '18690', '-44856']
# ['13', '-13377', '-7', '-165', '1485']
# ['40', '-35', '11', '-1456', '5096']
# Average feature:  2.5180803109373495
#
# =======================
# comparison__closest.txt
# =======================
#
# train-easy
#
# ['-1', '3', '-8', '7', '5', '-1.3']
# ['2.8', '2', '7', '0.2', '-0.1', '-4']
# ['0', '15', '-0.4', '1', '-6', '5']
# Average feature:  1.5811108703965444
#
# train-medium
#
# ['-1', '4', '2', '15', '1', '2', '4.1', '3']
# ['-1', '-49', '-0.247', '0.024', '-1']
# ['-1', '18', '32', '0.5', '-1', '11']
# Average feature:  1.7206894581623826
#
# train-hard
#
# ['2', '-7659', '7', '-2', '4', '0.14']
# ['-120', '-1', '2', '-3', '232', '3', '8', '3', '-1']
# ['-4', '4', '60', '0.6', '-2912']
# Average feature:  1.8650116631636233
#
# ===========================
# comparison__kth_biggest.txt
# ===========================
#
# train-easy
#
# ['2', '13', '5', '0.7']
# ['3', '5', '2.7', '0.3', '-1', '3']
# ['-10', '0.2', '-5', '4']
# Average feature:  1.6299151367604823
#
# train-medium
#
# ['-5', '291577', '-0.9', '0.3', '0.2']
# ['-1', '37', '7', '1', '-0.2', '3']
# ['4', '-1', '4', '1610', '1']
# Average feature:  1.8330288415515499
#
# train-hard
#
# ['0.1', '14', '305', '-1', '-0.136', '1']
# ['-19', '2', '-2', '375', '0.4', '9', '4', '0.3']
# ['132', '3', '0', '1', '17408', '9']
# Average feature:  2.021108864786123
#
# ====================
# comparison__sort.txt
# ====================
#
# train-easy
#
# ['-534', '4', '3']
# ['-0.1', '-1', '3', '-4', '120']
# ['-3.53', '-3', '2']
# Average feature:  1.9822404953358985
#
# train-medium
#
# ['221', '-2', '80', '-5', '-1']
# ['15600', '9', '1']
# ['-5', '7', '-26', '22', '0']
# Average feature:  2.2903764709502856
#
# train-hard
#
# ['198', '-45', '5', '-2', '-18', '2', '3']
# ['-23', '-56', '-1', '5', '-18']
# ['5', '4', '1', '7742', '-56', '9', '1', '5']
# Average feature:  2.6013033343664347
#
# ===========================
# measurement__conversion.txt
# ===========================
#
# train-easy
#
# []
# ['15', '4']
# ['41', '2']
# Average feature:  5.692215442215442
#
# train-medium
#
# []
# ['3140.836']
# []
# Average feature:  5.685025935025935
#
# train-hard
#
# ['3', '5']
# ['1.191609']
# ['1794.8985']
# Average feature:  5.676905676905677
#
# ========================
# numbers__place_value.txt
# ========================
#
# train-easy
#
# ['31253']
# ['63']
# ['826']
# Average feature:  2.6158098658098656
#
# train-medium
#
# ['80577']
# ['125343']
# ['17715170']
# Average feature:  3.788163038163038
#
# train-hard
#
# ['9967193']
# ['727180906']
# ['12460358']
# Average feature:  4.9446439446439445
#
# =========================
# numbers__round_number.txt
# =========================
#
# train-easy
#
# ['-0.0006832', '5']
# ['54.731', '10']
# ['6287000', '1000000']
# Average feature:  6.1296582546582545
#
# train-medium
#
# ['1.72315']
# ['0.00005280753', '6']
# ['0.007814012', '6']
# Average feature:  7.010625635625636
#
# train-hard
#
# ['-4483293740', '100000']
# ['-0.00000150450395', '6']
# ['-3820.654729', '100']
# Average feature:  7.977471102471102
#
# ================================
# probability__swr_p_level_set.txt
# ================================
#
# train-easy
#
# ['1', '1']
# ['1', '1']
# ['1', '2']
# Average feature:  1.3613762271497651
#
# train-medium
#
# ['1', '2']
# ['5', '2', '2']
# ['5', '3', '2', '5', '4', '2']
# Average feature:  1.3614191129069246
#
# train-hard
#
# ['2', '1']
# ['12', '7', '1', '1']
# ['1', '1', '1']
# Average feature:  1.3615534163150407
#
# ===============================
# probability__swr_p_sequence.txt
# ===============================
#
# train-easy
#
# []
# []
# ['6', '1', '4', '3', '1', '4']
# Average feature:  1.1667649292647273
#
# train-medium
#
# ['12', '6', '1']
# []
# ['5', '6', '2']
# Average feature:  1.1669024794022818
#
# train-hard
#
# []
# ['7', '2', '3']
# ['2', '4']
# Average feature:  1.1663453288451366

# %%
float_results
# Out:
# {'train-easy/algebra__polynomial_roots.txt': 2.7458457458457457,
#  'train-medium/algebra__polynomial_roots.txt': 4.625938625938626,
#  'train-hard/algebra__polynomial_roots.txt': 6.743892743892744,
#  'train-easy/arithmetic__add_or_sub.txt': 5.868015618015618,
#  'train-medium/arithmetic__add_or_sub.txt': 8.882789132789133,
#  'train-hard/arithmetic__add_or_sub.txt': 11.964767214767214,
#  'train-easy/arithmetic__add_sub_multiple.txt': 1.8752853752853753,
#  'train-medium/arithmetic__add_sub_multiple.txt': 2.418852918852919,
#  'train-hard/arithmetic__add_sub_multiple.txt': 2.8447160947160945,
#  'train-easy/arithmetic__div.txt': 3.186057186057186,
#  'train-medium/arithmetic__div.txt': 4.878652878652878,
#  'train-hard/arithmetic__div.txt': 6.607759357759358,
#  'train-easy/arithmetic__mixed.txt': 2.2798575298575297,
#  'train-medium/arithmetic__mixed.txt': 2.8877466377466376,
#  'train-hard/arithmetic__mixed.txt': 3.519106269106269,
#  'train-easy/arithmetic__mul.txt': 4.583364083364083,
#  'train-medium/arithmetic__mul.txt': 6.358462858462858,
#  'train-hard/arithmetic__mul.txt': 8.282326532326532,
#  'train-easy/arithmetic__mul_div_multiple.txt': 2.2527105027105025,
#  'train-medium/arithmetic__mul_div_multiple.txt': 2.8486550986550987,
#  'train-hard/arithmetic__mul_div_multiple.txt': 3.471211221211221,
#  'train-easy/comparison__closest.txt': 2.3743396243396244,
#  'train-medium/comparison__closest.txt': 2.6891989391989393,
#  'train-hard/comparison__closest.txt': 3.058132558132558,
#  'train-easy/comparison__kth_biggest.txt': 2.3671358671358673,
#  'train-medium/comparison__kth_biggest.txt': 2.794025044025044,
#  'train-hard/comparison__kth_biggest.txt': 3.226181476181476,
#  'train-easy/comparison__sort.txt': 3.1515226515226513,
#  'train-medium/comparison__sort.txt': 3.9483744483744485,
#  'train-hard/comparison__sort.txt': 4.742157242157242,
#  'train-easy/measurement__conversion.txt': 5.739352989352989,
#  'train-medium/measurement__conversion.txt': 5.732052482052482,
#  'train-hard/measurement__conversion.txt': 5.723998223998224,
#  'train-easy/numbers__place_value.txt': 2.6158098658098656,
#  'train-medium/numbers__place_value.txt': 3.788163038163038,
#  'train-hard/numbers__place_value.txt': 4.9446439446439445,
#  'train-easy/numbers__round_number.txt': 6.7597117597117595,
#  'train-medium/numbers__round_number.txt': 7.860479610479611,
#  'train-hard/numbers__round_number.txt': 9.074499074499075,
#  'train-easy/probability__swr_p_level_set.txt': 1.6336358836358837,
#  'train-medium/probability__swr_p_level_set.txt': 1.6337956337956339,
#  'train-hard/probability__swr_p_level_set.txt': 1.6343071343071343,
#  'train-easy/probability__swr_p_sequence.txt': 1.5261457761457762,
#  'train-medium/probability__swr_p_sequence.txt': 1.5262477762477762,
#  'train-hard/probability__swr_p_sequence.txt': 1.525927525927526}
